# %%
Задание 1: группировка и отображение максимального результата по условию

Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. 
Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd
ds=pd.read_csv('ratings.csv', 'r', delimiter=',')
ds[ds['rating']==5.0]['movieId'].value_counts().head(1)
# Out:
# 318    48762
# Name: movieId, dtype: int64

# %%
Задание 2: группировка и отображение максимального результата по условию

По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) 
категорий 4, 12 и 21 за период с 2005 по 2010 года. 
Не учитывайте в расчетах отрицательные значения quantity.

# %%
summ=0
ds=pd.read_csv('power.csv', 'r', delimiter=',')
ds2=ds[(ds['year']>=2005)&(ds['year']<=2010)&(ds['quantity']>0)]
ds3=ds2[ds2.category.isin([4,12,21])]
summ=ds3[ds3.country.str.contains('|'.join(['Lat','Lit','Est']))]['quantity'].sum()
print('суммарное потребление: {}'.format(summ))
# Out:
# суммарное потребление: 240580.0

# %%
Задание 3
Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.

# %%
import pandas as pd

tables = pd.read_html("https://fortrader.org/quotes")

print(tables)
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  86.34       0.01          0.01        NaN
# 1       USDRUB Курс рубля к доллару  73.07      -0.01         -0.02        NaN,                               Название    Цена  Изменение  Изменение(%)  \
# 0       Нефть Brent Курс нефти сегодня   75.10       0.00          0.00
# 1          Нефть WTI Цены на нефть WTI   73.70      -0.02         -0.03
# 2  Природный газ Цена на природный газ    3.92      -0.00         -0.03
# 3                                 Кофе  180.40       0.00          0.00
# 4                             Кукуруза  546.60       0.00          0.00
# 5                                  Соя  356.50       5.60          1.60
# 6                               Хлопок   89.39       0.00          0.00
#
#    Обновлено
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN  ,                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0       Золото Цена золота на бирже  1 815      -1.00         -0.00        NaN
# 1  Серебро Цена на серебро на бирже  25.49       0.01          0.05        NaN
# 2         Палладий Цена на Палладий  2 661       1.00          0.00        NaN
# 3           Платина Цены на платину  1 045       0.00          0.00        NaN
# 4           Медь Цена меди на бирже   4.48      -0.00         -0.07        NaN,                                         Название      Цена   Изменение  \
# 0                                  ВТБ Акции ВТБ  0.048425   -0.000035
# 1                         Газпром Акции газпрома    287.20   -0.150000
# 2                            Лукойл Акции Лукойл   6 293.0   -6.000000
# 3                        Роснефть Акции Роснефти    544.20   -0.300000
# 4                       Сбербанк Акции Сбербанка    305.44   -0.150000
# 5           Сургутнефтегаз Акции Сургутнефтегаза    32.455   -0.010000
# 6                      Норникель Акции Норникель    25 318    0.000000
# 7                       Аэрофлот Акции Аерофлота     67.06   -0.100000
# 8                    Северсталь Акции Северсталь  1 799.00   -0.400000
# 9                    Транснефть Акции Транснефть   162 550 -100.000000
# 10             Ростелеком Курс акций ростелекома     93.42   -0.090000
# 11                      РУСАЛ Акции РУСАЛ (RUAL)    51.955   -0.005000
# 12      Детский мир iDreamSky Technology Limited    140.18    0.000000
# 13             Петропавловск Акции Петропавловск     21.36   -0.040000
# 14                    Алроса Акции АЛРОСА (ALRS)   130.560   -0.010000
# 15                    Магнит Акции Магнит (MGNT)   5 337.0    0.000000
# 16                        НМЛК Акции НЛМК (NLMK)   258.300   -0.200000
# 17                  М.видео Акции М.видео (MVID)    639.90   -0.700000
# 18    Газпром нефть Акции "Газпром нефть" (SIBN)    424.15    0.000000
# 19                        НМТП Акции НМТП (NMTP)    7.2000    0.000000
# 20            Полиметалл Акции Полиметалл (POLY)  1 592.10   -0.300000
# 21        Полюс Золото Акции Полюс Золото (PLZL)  13 994.5   -5.500000
# 22                  НОВАТЭК Акции НОВАТЭК (NVTK)  1 631.00   -2.800000
# 23                РусГидро Акции РусГидро (HYDR)    0.8116   -0.000900
# 24                Татнефть Акции Татнефть (TATN)    488.80    0.400000
# 25        АФК Система Акции АФК "Система" (AFKS)    29.660   -0.001000
# 26                                 МТС Акции МТС    316.05   -0.050000
# 27                Башнефть Акции Башнефть (BANE)   1 400.5    0.000000
# 28                    Яндекс Акции Яндекс (YNDX)   4 970.4    0.000000
# 29  X5 Retail Group Акции X5 Retail Group (FIVE)  2 377.50   -0.500000
# 30                  ФСК ЕЭС Акции ФСК ЕЭС (FEES)   0.20190   -0.000060
# 31                      Мечел Акции Мечел (MTLR)     80.57   -0.120000
# 32                МосБиржа Акции МосБиржа (MOEX)    173.40   -0.010000
# 33              Интер РАО Акции Интер РАО (IRAO)      4.37   -0.000000
# 34              Mail.ru Акции Mail.ru (MAIL, ДР)  1 513.80   -1.000000
# 35                        Киви Акции Киви (QIWI)     746.5    0.000000
# 36                  Лента Акции Лента (LNTA, ДР)    233.50   -0.200000
# 37            Тинькофф Акции Тинькофф (TCSG, др)  6 112.00   -1.800000
# 38                        Озон Акции Озон (Ozon)  3 816.50   -2.500000
#
#     Изменение(%)  Обновлено
# 0      -0.072225        NaN
# 1      -0.050000        NaN
# 2      -0.100000        NaN
# 3      -0.060000        NaN
# 4      -0.050000        NaN
# 5      -0.031000        NaN
# 6       0.000000        NaN
# 7      -0.150000        NaN
# 8      -0.020000        NaN
# 9      -0.000000        NaN
# 10     -0.100000        NaN
# 11     -0.010000        NaN
# 12      0.000000        NaN
# 13     -0.190000        NaN
# 14     -0.008000        NaN
# 15      0.000000        NaN
# 16     -0.077000        NaN
# 17     -0.110000        NaN
# 18      0.000000        NaN
# 19      0.000000        NaN
# 20     -0.020000        NaN
# 21     -0.000000        NaN
# 22     -0.170000        NaN
# 23     -0.110800        NaN
# 24      0.080000        NaN
# 25     -0.003000        NaN
# 26     -0.020000        NaN
# 27      0.000000        NaN
# 28      0.000000        NaN
# 29     -0.020000        NaN
# 30     -0.029710        NaN
# 31     -0.150000        NaN
# 32     -0.010000        NaN
# 33     -0.070000        NaN
# 34     -0.070000        NaN
# 35      0.000000        NaN
# 36     -0.090000        NaN
# 37     -0.030000        NaN
# 38     -0.070000        NaN  ,                                Название      Цена  Изменение  Изменение(%)  \
# 0           Google Акции Google (GOOGL)  2 694.57       0.04          0.00
# 1                   IBM Акции IBM (IBM)    141.00       0.04          0.03
# 2     Microsoft Акции Майкрософт (MSFT)    284.97       0.06          0.02
# 3              Apple Акции Apple (AAPL)    145.88       0.02          0.01
# 4                  Yandex Акции яндекса     67.90      -0.03         -0.04
# 5                   Toyota Акции Тойоты    179.43      -0.41         -0.23
# 6      Volkswagen Курс акций Volkswagen    205.85      -0.10         -0.05
# 7            Amazon Акции Amazon (AMZN)  3 328.00       0.41          0.01
# 8           Boeing Акции Boeing Company    226.53       0.05          0.02
# 9              Intel Акции Intel (INTC)     53.72       0.00          0.00
# 10            Coca-Cola Акции Coca-Cola     57.06       0.03          0.05
# 11         Netflix Акции Netflix (NFLX)    517.25      -0.32         -0.06
# 12            Pfizer Акции Pfizer (PFE)     42.85       0.04          0.09
# 13                        AMD Акции AMD    106.22       0.03          0.03
# 14  Walt Disney Акции Walt Disney (DIS)    176.02       0.00          0.00
# 15           NVIDIA Акции NVIDIA (NVDA)    195.04       0.05          0.03
# 16           PayPal Акции PayPal (PYPL)    275.25      -0.28         -0.10
# 17         Facebook Акции Facebook (FB)    356.35       0.05          0.01
# 18             Tesla Акции Тесла (TSLA)    687.31       0.11          0.02
# 19            Twiter Цена акций твитера     69.76       0.01          0.01
# 20    Hasbro Цена на акции Hasbro, Inc.     96.03      -3.41         -3.43
# 21                               Сименс    131.80      -0.20         -0.15
# 22                                 Qiwi     10.18      -0.02         -0.20
# 23     Mastercard Акции Mastercard (МА)    385.94       0.00          0.00
# 24         Moderna Акции Модерна (MRNA)    353.75       0.15          0.04
# 25        Макдональдс Акции Макдональдс    242.72       0.01          0.00
# 26                                 MSCI    497.12     -98.84        -16.59
# 27                             FIXPRICE      7.64      -0.01         -0.13
# 28                 Zoom Акции Zoom (ZM)    377.45      -0.65         -0.17
# 29     HeadHunter Акции HeadHunter (HH)     41.82      -0.81         -1.90
#
#     Обновлено
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN  ,   Название      Цена  Изменение  Изменение(%)  Обновлено
# 0     FXIT  11 291.0    -1.0000       -0.0000        NaN
# 1     FXRU     946.0    -0.8000       -0.1000        NaN
# 2     FXDE   3 081.0    -4.5000       -0.1000        NaN
# 3     FXCN   3 300.5    -4.5000       -0.1000        NaN
# 4     FXGD    893.20     0.0000        0.0000        NaN
# 5     FXWO    1.8269    -0.0001       -0.0055        NaN,                                          Название       Цена  Изменение  \
# 0         Индекс МосБиржи Индекс МосБиржи (IMOEX)    379 450    -200.00
# 1                    Индекс РТС Индекс РТС (RTSI)   1 625.76       0.00
# 2                      Dow Jones Индекс Dow Jones  34 935.50       0.00
# 3                          S&P 500 Индекс S&P 500      4 395       0.00
# 4                    Nasdaq 100 Индекс Nasdaq 100  14 959.90       0.00
# 5   Euro Stoxx 50 Индекс Euro Stoxx 50 (STOXX50E)    4 090.3       0.00
# 6                            FTSE 100 Индекс FTSE   7 032.30       0.00
# 7             Nikkei 225 Индекс Nikkei 225 (N225)     27 479       0.00
# 8                Russell 2000 Индекс Russell 2000   2 226.25       0.00
# 9                              DAX30 Индекс DAX30   15 495.1       0.00
# 10                           CAC 40 Индекс CAC 40    6 619.1       0.00
# 11                         IBEX 35 Индекс IBEX 35    8 668.3       0.00
# 12                         ASX 200 Индекс ASX 200    7 418.5       1.00
# 13        Фьючерс РТС Курс фьючерса на индекс РТС    162 270      10.00
# 14                                      USD INDEX      92.08       0.01
#
#     Изменение(%)  Обновлено
# 0          -0.00        NaN
# 1           0.00        NaN
# 2           0.00        NaN
# 3           0.00        NaN
# 4           0.00        NaN
# 5           0.00        NaN
# 6           0.00        NaN
# 7           0.00        NaN
# 8           0.00        NaN
# 9           0.00        NaN
# 10          0.00        NaN
# 11          0.00        NaN
# 12          0.00        NaN
# 13          0.00        NaN
# 14          0.01        NaN  ,                                            Название       Цена  Изменение  \
# 0                         EUR/USD Евро / Доллар США    1.18720   -0.00018
# 1                         GBP/USD Фунт / Доллар США    1.39060   -0.00027
# 2                            USD/CHF Доллар / Франк    0.90496   -0.00013
# 3                         USD/JPY Доллар США / Иена  109.64900   -0.02700
# 4                             USD/CNH Доллар / Юань    6.45940   -0.00140
# 5             USD/CAD Доллар США / Канадский доллар    1.24629    0.00002
# 6         AUD/USD Австралийский доллар / Доллар США    0.73460   -0.00006
# 7                              EUR/CHF Евро / Франк    1.07437   -0.00020
# 8   AUD/CAD Австралийский доллар / Канадский доллар    0.91553   -0.00002
# 9                      EUR/JPY Евро / Японская йена  130.17700   -0.04300
# 10                              EUR/GBP Евро / Фунт    0.85349   -0.00013
# 11                              GBP/JPY Фунт / Йена  152.48100   -0.05000
# 12            NZDUSD New Zealand Dollar / US Dollar    0.69752   -0.00013
#
#     Изменение(%)  Обновлено
# 0       -0.01516        NaN
# 1       -0.01941        NaN
# 2       -0.01436        NaN
# 3       -0.02500        NaN
# 4       -0.02170        NaN
# 5        0.00160        NaN
# 6       -0.00817        NaN
# 7       -0.01861        NaN
# 8       -0.00218        NaN
# 9       -0.03300        NaN
# 10      -0.01523        NaN
# 11      -0.03300        NaN
# 12      -0.01863        NaN  ,                                              Название       Цена  Изменение  \
# 0                               Bitcoin Курс биткоина  40 725.80 -265.00000
# 1          Litecoin Курс лайткоин к доллару (LTC/USD)      142.3   -2.00000
# 2   BitcoinCash Курс Биткоин кеш к доллару США (BC...     540.80   -0.73000
# 3                                           Dash Dash     160.52   -2.43000
# 4                                       Ripple Ripple    0.75042    0.00537
# 5                                   Ethereum Ethereum   2 417.21   -4.28000
# 6                                         Zcash (ZEC)     107.24   -3.76000
# 7                                           NEO (NEO)     37.523   -8.18300
# 8                                           EOS (EOS)     3.9444   -0.11500
# 9                                          TRON (TRX)    0.06226   -0.00165
# 10                                             Monero     239.76   -0.15000
# 11                                               IOTA    0.80076   -0.11557
# 12                       ETC/USD эфириум классик, ETC     49.962   -1.14200
#
#     Изменение(%)  Обновлено
# 0       -0.65000        NaN
# 1       -1.40000        NaN
# 2       -0.13000        NaN
# 3       -1.49000        NaN
# 4        0.72076        NaN
# 5       -0.18000        NaN
# 6       -3.39000        NaN
# 7      -17.90400        NaN
# 8       -2.83290        NaN
# 9       -2.57871        NaN
# 10      -0.06000        NaN
# 11     -12.61227        NaN
# 12      -2.23500        NaN  ]
